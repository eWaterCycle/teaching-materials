# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import HBVMod_own
import A_MC_HBV 
import B_PlotRes
# Out:
# 1163
# 1163
# C:\Users\anne-\OneDrive - Delft University of Technology\Documenten\Environmental Engineering MSc\ENVM1502 River Basin Hydrology\Unit 3\Exercise 3\B_PlotRes.py:76: UserWarning: Glyph 8 ) missing from current font.
#   plt.tight_layout()
# C:\Users\anne-\anaconda3\envs\ENVM1502\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8 ) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

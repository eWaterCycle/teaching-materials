# %% [markdown]
# | Category                     | Tasks Completed                               | File Name |
# |------------------------------|-----------------------------------------------|-----------|
# | **Assignments from Practicals** <br> *(Mannings River unless noted)* | Budyko Processes <br> Vegetation Processes <br> Snow Processes (Rhine) <br> Closing Water Balance | 1_processes_Budyko.ipynb <br> 2_processes_vegetation.ipynb <br> 4_processes_snow.ipynb <br> closing_water_balance_manning.ipynb <br>          |
# | **eWaterCycle**              | Build test HBV <br> Generate ERA5 Forcing <br> Run HBV <br> Calibrate & Validate HBV <br> Generate CMIP6 Forcing | exercise1 <br> exercise2 <br> exercise3 <br> exercise4 <br> exercise5 <br>           |
# | **FlexTopo**                 | Calibration <br> Model Analysis (Hillslope)   | FlexTopo/calibration_flextopo <br> FlexTopo/exercise_flextopo          |

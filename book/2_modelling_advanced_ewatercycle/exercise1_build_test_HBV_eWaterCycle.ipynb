# %% [markdown]
# # Exercise 1. Test your own HBV model on eWaterCycle
#
# For more information on eWaterCycle: [getting started page](https://www.ewatercycle.org/getting-started/main/intro.html)!
#
# In this exercise you are asked to create a HBV model in a separate Python file which will be imported here. This notebook can then be used to run and check your HBV model, the notebook also imports the relevant packages needed to run it on eWaterCycle.
#
# In this folder you can find a file called ```hbv_bmi.py```. Open that file and look for the function called update, ie ```def update(self) -> None:```. If you look closely you will see that this is the 'core' of HBV. As you can see, most of the variables are set to zero, which is, of course, incorrect. Change this part as you learned in the HBV exercise, but make sure you use ```self.var``` instead of ```var``` for any variable. For example: ```self.Si = self.Si + self.P_dt```. This way of coding is needed because we are creating a HBV class here that we can use later. (Remember your programming classes in MUDE and before).
#
# Once you have added your HBV code, save the file and run the notebook below. Read carefully, you will have to change some things yourself. The first part will create a hydrograph in which you can compare your calculated discharge with the reference discharge. In the second part, a test case is created which will check your model with a pre-defined parameter set and initial storages. Optionally, in the third part you can create a test case yourself.
#
# **Important:**
# Anytime you edit the code in ```hbv_bmi.py```, it is important to restart the kernel and re-run the cells, to make sure your changes are imported (in cell 3 below)

# %% [markdown]
# ## 1.1. Import packages

# %%
# General python
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from rich import print

# %%
# %pip install ewatercycle
# eWaterCycle packages
import ewatercycle
from ewatercycle.base.forcing import GenericLumpedForcing
# Out:
# Requirement already satisfied: ewatercycle in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (2.4.0)
# Requirement already satisfied: bmipy in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from ewatercycle) (2.0.1)
# Requirement already satisfied: cartopy in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from ewatercycle) (0.25.0)
# Requirement already satisfied: cftime>=1.6.2 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from ewatercycle) (1.6.5)
# Requirement already satisfied: fiona in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from ewatercycle) (1.10.1)
# Requirement already satisfied: fsspec in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from ewatercycle) (2026.2.0)
# Requirement already satisfied: grpc4bmi>=0.4.0 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from ewatercycle) (0.5.0)
# Requirement already satisfied: hydrostats in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from ewatercycle) (1.0.0)
# Requirement already satisfied: matplotlib>=3.5.0 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from ewatercycle) (3.10.6)
# Requirement already satisfied: numpy in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from ewatercycle) (2.3.2)
# Requirement already satisfied: pandas in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from ewatercycle) (2.3.2)
# Requirement already satisfied: pydantic>=2 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from ewatercycle) (2.12.5)
# Requirement already satisfied: pyoos in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from ewatercycle) (0.8.4)
# Requirement already satisfied: pyopenssl>=24.0.0 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from ewatercycle) (26.0.0)
# Requirement already satisfied: python-dateutil in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from ewatercycle) (2.9.0.post0)
# Requirement already satisfied: remotebmi in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from ewatercycle) (0.1.0)
# Requirement already satisfied: ruamel-yaml in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from ewatercycle) (0.19.1)
# Requirement already satisfied: shapely in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from ewatercycle) (2.1.2)
# Requirement already satisfied: xarray in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from ewatercycle) (2026.2.0)
# Requirement already satisfied: grpcio in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from grpc4bmi>=0.4.0->ewatercycle) (1.78.0)
# Requirement already satisfied: grpcio-reflection in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from grpc4bmi>=0.4.0->ewatercycle) (1.62.3)
# Requirement already satisfied: grpcio-status in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from grpc4bmi>=0.4.0->ewatercycle) (1.62.3)
# Requirement already satisfied: googleapis-common-protos>=1.5.5 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from grpc4bmi>=0.4.0->ewatercycle) (1.73.0)
# Requirement already satisfied: protobuf<5,>=4 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from grpc4bmi>=0.4.0->ewatercycle) (4.25.9)
# Requirement already satisfied: docker in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from grpc4bmi>=0.4.0->ewatercycle) (7.1.0)
# Requirement already satisfied: packaging in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from grpc4bmi>=0.4.0->ewatercycle) (25.0)
# Requirement already satisfied: typeguard in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from grpc4bmi>=0.4.0->ewatercycle) (4.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from matplotlib>=3.5.0->ewatercycle) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from matplotlib>=3.5.0->ewatercycle) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from matplotlib>=3.5.0->ewatercycle) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from matplotlib>=3.5.0->ewatercycle) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from matplotlib>=3.5.0->ewatercycle) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from matplotlib>=3.5.0->ewatercycle) (3.2.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from pydantic>=2->ewatercycle) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from pydantic>=2->ewatercycle) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from pydantic>=2->ewatercycle) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from pydantic>=2->ewatercycle) (0.4.2)
# Requirement already satisfied: cryptography<47,>=46.0.0 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from pyopenssl>=24.0.0->ewatercycle) (46.0.6)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from cryptography<47,>=46.0.0->pyopenssl>=24.0.0->ewatercycle) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from cffi>=2.0.0->cryptography<47,>=46.0.0->pyopenssl>=24.0.0->ewatercycle) (2.22)
# Requirement already satisfied: six>=1.5 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from python-dateutil->ewatercycle) (1.17.0)
# Requirement already satisfied: black in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from bmipy->ewatercycle) (26.3.1)
# Requirement already satisfied: click in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from bmipy->ewatercycle) (8.3.1)
# Requirement already satisfied: jinja2 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from bmipy->ewatercycle) (3.1.6)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from black->bmipy->ewatercycle) (1.1.0)
# Requirement already satisfied: pathspec>=1.0.0 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from black->bmipy->ewatercycle) (1.0.4)
# Requirement already satisfied: platformdirs>=2 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from black->bmipy->ewatercycle) (4.4.0)
# Requirement already satisfied: pytokens~=0.4.0 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from black->bmipy->ewatercycle) (0.4.1)
# Requirement already satisfied: colorama in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from click->bmipy->ewatercycle) (0.4.6)
# Requirement already satisfied: pyshp>=2.3 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from cartopy->ewatercycle) (3.0.3)
# Requirement already satisfied: pyproj>=3.3.1 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from cartopy->ewatercycle) (3.7.2)
# Requirement already satisfied: certifi in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from pyproj>=3.3.1->cartopy->ewatercycle) (2026.2.25)
# Requirement already satisfied: pywin32>=304 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from docker->grpc4bmi>=0.4.0->ewatercycle) (311)
# Requirement already satisfied: requests>=2.26.0 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from docker->grpc4bmi>=0.4.0->ewatercycle) (2.32.5)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from docker->grpc4bmi>=0.4.0->ewatercycle) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from requests>=2.26.0->docker->grpc4bmi>=0.4.0->ewatercycle) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from requests>=2.26.0->docker->grpc4bmi>=0.4.0->ewatercycle) (3.10)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from fiona->ewatercycle) (25.3.0)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from fiona->ewatercycle) (1.1.1.2)
# Requirement already satisfied: cligj>=0.5 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from fiona->ewatercycle) (0.7.2)
# Requirement already satisfied: hydroerr~=2.0 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from hydrostats->ewatercycle) (2.0.0)
# Requirement already satisfied: numba~=0.63.0 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from hydrostats->ewatercycle) (0.63.1)
# Requirement already satisfied: scipy~=1.0 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from hydrostats->ewatercycle) (1.16.1)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from numba~=0.63.0->hydrostats->ewatercycle) (0.46.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from pandas->ewatercycle) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from pandas->ewatercycle) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from jinja2->bmipy->ewatercycle) (3.0.2)
# Requirement already satisfied: paegan>=1.1 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from pyoos->ewatercycle) (1.1.4)
# Requirement already satisfied: OWSLib>=0.8.3 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from pyoos->ewatercycle) (0.35.0)
# Requirement already satisfied: beautifulsoup4>=4.2.1 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from pyoos->ewatercycle) (4.13.5)
# Requirement already satisfied: lxml>=3.2.0 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from pyoos->ewatercycle) (6.0.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from beautifulsoup4>=4.2.1->pyoos->ewatercycle) (2.8)
# Requirement already satisfied: pyyaml in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from OWSLib>=0.8.3->pyoos->ewatercycle) (6.0.2)
# Requirement already satisfied: netCDF4>=1.0.2 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from paegan>=1.1->pyoos->ewatercycle) (1.7.4)
# Requirement already satisfied: connexion in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from remotebmi->ewatercycle) (3.3.0)
# Requirement already satisfied: httpx>=0.27.2 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from remotebmi->ewatercycle) (0.28.1)
# Requirement already satisfied: uvicorn in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from remotebmi->ewatercycle) (0.42.0)
# Requirement already satisfied: anyio in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from httpx>=0.27.2->remotebmi->ewatercycle) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from httpx>=0.27.2->remotebmi->ewatercycle) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from httpcore==1.*->httpx>=0.27.2->remotebmi->ewatercycle) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from anyio->httpx>=0.27.2->remotebmi->ewatercycle) (1.3.1)
# Requirement already satisfied: asgiref>=3.4 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from connexion->remotebmi->ewatercycle) (3.11.1)
# Requirement already satisfied: inflection>=0.3.1 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from connexion->remotebmi->ewatercycle) (0.5.1)
# Requirement already satisfied: jsonschema>=4.17.3 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from connexion->remotebmi->ewatercycle) (4.25.1)
# Requirement already satisfied: python-multipart>=0.0.15 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from connexion->remotebmi->ewatercycle) (0.0.22)
# Requirement already satisfied: starlette>=0.35 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from connexion->remotebmi->ewatercycle) (1.0.0)
# Requirement already satisfied: werkzeug>=2.2.1 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from connexion->remotebmi->ewatercycle) (3.1.7)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from jsonschema>=4.17.3->connexion->remotebmi->ewatercycle) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from jsonschema>=4.17.3->connexion->remotebmi->ewatercycle) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\madis\tudelft-conda\envs\mude-base\lib\site-packages (from jsonschema>=4.17.3->connexion->remotebmi->ewatercycle) (0.27.1)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\madis\tudelft-conda\envs\mude-base\Lib\site-packages\ewatercycle\esmvaltool\diagnostic\copier.py:8
#       7 try:
# ----> 8     from esmvaltool.diag_scripts.shared import (
#       9         ProvenanceLogger,
#      10         get_diagnostic_filename,
#      11         run_diagnostic,
#      12     )
#      13 except ImportError as e:
#
# ModuleNotFoundError: No module named 'esmvaltool'
#
# The above exception was the direct cause of the following exception:
#
# ESMValToolNotFoundError                   Traceback (most recent call last)
# Cell In[8], line 4
#       2 # eWaterCycle packages
#       3 import ewatercycle
# ----> 4 from ewatercycle.base.forcing import GenericLumpedForcing
#
# File c:\Users\madis\tudelft-conda\envs\mude-base\Lib\site-packages\ewatercycle\base\forcing.py:51
#      48 from pyproj import Geod
#      49 from ruamel.yaml import YAML
# ---> 51 from ewatercycle.esmvaltool.builder import (
#      52     build_generic_distributed_forcing_recipe,
#      53     build_generic_lumped_forcing_recipe,
#      54 )
#      55 from ewatercycle.esmvaltool.run import run_recipe
#      56 from ewatercycle.esmvaltool.schema import Dataset, Recipe
#
# File c:\Users\madis\tudelft-conda\envs\mude-base\Lib\site-packages\ewatercycle\esmvaltool\builder.py:12
#       9 from typing import Literal
#      11 from ewatercycle.esmvaltool.datasets import DATASETS
# ---> 12 from ewatercycle.esmvaltool.diagnostic import copier
#      13 from ewatercycle.esmvaltool.schema import (
#      14     ClimateStatistics,
#      15     Dataset,
#    (...)     21     Variable,
#      22 )
#      23 from ewatercycle.util import get_extents
#
# File c:\Users\madis\tudelft-conda\envs\mude-base\Lib\site-packages\ewatercycle\esmvaltool\diagnostic\copier.py:16
#      13 except ImportError as e:
#      14     from ewatercycle.esmvaltool.missing import ESMValToolNotFoundError
# ---> 16     raise ESMValToolNotFoundError from e
#      18 logger = logging.getLogger(Path(__file__).name)
#      21 def main(cfg):
#
# ESMValToolNotFoundError: ESMValTool or ESMValCore packages have not been found.
#
# Likely because ewatercycle dependencies are not installed
# in a conda environment.
#
# Please install ewatercycle with:
#
# ```shell
# curl -o conda-lock.yml https://raw.githubusercontent.com/eWaterCycle/ewatercycle/main/conda-lock.yml
# conda install mamba conda-lock -n base -c conda-forge -y
# conda-lock install --no-dev -n ewatercycle
# conda activate ewatercycle
# pip install ewatercycle
# ```

# %%
# Packages for this exercise: are located in the same folder as this notebook!
from forcing import HBVForcing
from ewatercycle_wrapper_HBV import HBV  # This wrapper class imports YOUR hbv_bmi.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\madis\tudelft-conda\envs\mude-base\Lib\site-packages\ewatercycle\esmvaltool\diagnostic\copier.py:8
#       7 try:
# ----> 8     from esmvaltool.diag_scripts.shared import (
#       9         ProvenanceLogger,
#      10         get_diagnostic_filename,
#      11         run_diagnostic,
#      12     )
#      13 except ImportError as e:
#
# ModuleNotFoundError: No module named 'esmvaltool'
#
# The above exception was the direct cause of the following exception:
#
# ESMValToolNotFoundError                   Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Packages for this exercise: are located in the same folder as this notebook!
# ----> 2 from forcing import HBVForcing
#       3 from ewatercycle_wrapper_HBV import HBV  # This wrapper class imports YOUR hbv_bmi.py
#
# File c:\Users\madis\OneDrive\MSc EVEG\ENVM1502\project\teaching-materials\book\2_modelling_advanced_ewatercycle\forcing.py:12
#       9 import xarray as xr
#      10 import numpy as np
# ---> 12 from ewatercycle.base.forcing import DefaultForcing
#      15 RENAME_CAMELS = {'total_precipitation_sum':'pr',
#      16                       'potential_evaporation_sum':'"evspsblpot"',
#      17                       'streamflow':'Q'}
#      19 REQUIRED_PARAMS = ["pr", "evspsblpot"]
#
# File c:\Users\madis\tudelft-conda\envs\mude-base\Lib\site-packages\ewatercycle\base\forcing.py:51
#      48 from pyproj import Geod
#      49 from ruamel.yaml import YAML
# ---> 51 from ewatercycle.esmvaltool.builder import (
#      52     build_generic_distributed_forcing_recipe,
#      53     build_generic_lumped_forcing_recipe,
#      54 )
#      55 from ewatercycle.esmvaltool.run import run_recipe
#      56 from ewatercycle.esmvaltool.schema import Dataset, Recipe
#
# File c:\Users\madis\tudelft-conda\envs\mude-base\Lib\site-packages\ewatercycle\esmvaltool\builder.py:12
#       9 from typing import Literal
#      11 from ewatercycle.esmvaltool.datasets import DATASETS
# ---> 12 from ewatercycle.esmvaltool.diagnostic import copier
#      13 from ewatercycle.esmvaltool.schema import (
#      14     ClimateStatistics,
#      15     Dataset,
#    (...)     21     Variable,
#      22 )
#      23 from ewatercycle.util import get_extents
#
# File c:\Users\madis\tudelft-conda\envs\mude-base\Lib\site-packages\ewatercycle\esmvaltool\diagnostic\copier.py:16
#      13 except ImportError as e:
#      14     from ewatercycle.esmvaltool.missing import ESMValToolNotFoundError
# ---> 16     raise ESMValToolNotFoundError from e
#      18 logger = logging.getLogger(Path(__file__).name)
#      21 def main(cfg):
#
# ESMValToolNotFoundError: ESMValTool or ESMValCore packages have not been found.
#
# Likely because ewatercycle dependencies are not installed
# in a conda environment.
#
# Please install ewatercycle with:
#
# ```shell
# curl -o conda-lock.yml https://raw.githubusercontent.com/eWaterCycle/ewatercycle/main/conda-lock.yml
# conda install mamba conda-lock -n base -c conda-forge -y
# conda-lock install --no-dev -n ewatercycle
# conda activate ewatercycle
# pip install ewatercycle
# ```

# %% [markdown]
# In this exercise we are using the same forcing data as you used in the earlier exercise. eWaterCycle works with forcing objects that contain all the information needed. It is important to set the paths to these files, so Python can find them:

# %%
path = Path.cwd()
forcing_path = path / "Forcing"

# %% [markdown]
# Specify dates for which to run the experiment. These dates align with the start and end dates in ```Forcing.txt```.

# %%
experiment_start_date = "1997-08-01T00:00:00Z"
experiment_end_date = "2000-08-31T00:00:00Z"

# %% [markdown]
# The next cell will generate the forcing for the HBV model. By using this function, the forcing is in the correct format for eWaterCycle.

# %%
test_forcing = HBVForcing(start_time = experiment_start_date,
                          end_time = experiment_end_date,
                          directory = forcing_path,
                          camels_file = f'Forcing.txt',
                          test_data_bool = True
                          )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 test_forcing = HBVForcing(start_time = experiment_start_date,
#       2                           end_time = experiment_end_date,
#       3                           directory = forcing_path,
#       4                           camels_file = f'Forcing.txt',
#       5                           test_data_bool = True
#       6                           )
#
# NameError: name 'HBVForcing' is not defined

# %% [markdown]
# The initial storages and parameters need to be set. For the parameters, the minimum and maximum value for each parameter is defined and the average value is used as input.

# %%
param_names = ["Imax","Ce",  "Sumax", "beta",  "Pmax",  "Tlag",   "Kf",   "Ks"]
p_min_initial= np.array([0,   0.2,  40,    .5,   .001,   1,     .01,  .0001])
p_max_initial = np.array([8,    1,  800,   4,    .3,     10,    .1,   .01])
S_names = ["Interception storage", "Unsaturated Rootzone Storage", "Fastflow storage", "Groundwater storage"]
s_0 = np.array([0,  100,  0,  5])
par_0 = (p_min_initial + p_max_initial)/2  # average value

# %% [markdown]
# ## 1.2. Create model instance
# Here we create an instance of the HBV class. If you are interested in how this is created, you can open the file ```ewatercycle_wrapper_HBV.py``` and have a look at the code. In this file the HBV class is defined, and as you can see it imports your ```hbv_bmi``` class that you written and saved in ```hbv_bmi.py```.
#
# After creating the model object, we need to perform two steps: generating a configuration file for the model and then initializing the model (with the ```initialize``` function). This step ensures that all the correct values are placed in the right memory locations. While a simple model like HBV could theoretically combine these steps, eWaterCycle requires them to be separate to maintain compatibility with more complex models such as WFLOW, PCRGlobWB, and LISFlood.

# %%
model = HBV(forcing=test_forcing)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 model = HBV(forcing=test_forcing)
#
# NameError: name 'HBV' is not defined

# %%
config_file, _ = model.setup(
                            parameters=','.join([str(p) for p in par_0]),
                            initial_storage=','.join([str(s) for s in s_0]),
                               )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 config_file, _ = model.setup(
#       2                             parameters=','.join([str(p) for p in par_0]),
#       3                             initial_storage=','.join([str(s) for s in s_0]),
#       4                                )
#
# NameError: name 'model' is not defined

# %%
model.initialize(config_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 model.initialize(config_file)
#
# NameError: name 'model' is not defined

# %%
print(test_forcing)
print(model)
# Out:
# HBVForcing(
#     start_time='1997-08-01T00:00:00Z',
#     end_time='2000-08-31T00:00:00Z',
#     directory=PosixPath('/home/aversleije/repos/teaching-materials/teaching-files/ENVM1502/source/ps1/Forcing'),
#     shape=None,
#     filenames={},
#     camels_file='Forcing.txt',
#     pr='HBV_forcing_test_2024-06-14 14_19.nc',
#     evspsblpot='HBV_forcing_test_2024-06-14 14_19.nc',
#     alpha=1.26,
#     test_data_bool=True
# )
# HBV(
#     parameter_set=None,
#     forcing=HBVForcing(
#         start_time='1997-08-01T00:00:00Z',
#         end_time='2000-08-31T00:00:00Z',
#         directory=PosixPath('/home/aversleije/repos/teaching-materials/teaching-files/ENVM1502/source/ps1/Forcing')
# ,
#         shape=None,
#         filenames={},
#         camels_file='Forcing.txt',
#         pr='HBV_forcing_test_2024-06-14 14_19.nc',
#         evspsblpot='HBV_forcing_test_2024-06-14 14_19.nc',
#         alpha=1.26,
#         test_data_bool=True
#     )
# )

# %% [markdown]
# ## 1.3. Run the Model
#
# This is the core cell where the model is run. The timesteps are based on the time defined in the ```Forcing.txt``` file, so in this case, each timestep is equal to 1 day.
# For each timestep, the model object is asked to update with the functions you created in the HBV model. With ```model.get_value("var")``` the value of the asked variable is returned, which is in this case the calculated discharge. Note that ```model.get_value("var")``` always returns a numpy array, even if the variable is only one value, as is the case here. The timestep is added as a datetime object to list called ```time```, this can be used later for plotting.
#
# The model object is updated until ```model.end_time```, this equal the last time index in ```Forcing.txt```.

# %%
Q_m = []
time = []
while model.time < model.end_time:
    model.update()
    discharge_this_timestep = model.get_value("Q")
    
    # Append the lists we just created
    Q_m.append(discharge_this_timestep[0])
    time.append(pd.Timestamp(model.time_as_datetime.date()))

# %% [markdown]
# It is good practice to remove your model from memory once you are done with it. For a small model as this HBV model, this may not be crucial, but for larger models that runs inside the software containers, it is essential to shut these containers down to free up the memory, CPU and hard disk space. This can be accomplished using the finalize command.

# %%
model.finalize()

# %% [markdown]
# ## 1.4. Visualize results
#
# The output generated in the previous step will be visualized here. To do so, the discharge and time lists are added to a dataframe to quickly plot the results.
#
# To be able to see how accurately your HBV model works, we will compare it with the reference (observed) discharge. This is saved in the file ```Q_m_out_ref.txt```, which we first need to import.

# %%
df = pd.DataFrame(data=Q_m,columns=["Modeled discharge"], index=time)

# %%
Q_ref = np.loadtxt('Forcing/Q_m_out_ref.txt')

# %%
fig, ax = plt.subplots(1,1)
df.plot(ax=ax, label="Modeled discharge HBV-bmi")
plt.plot(time, Q_ref[1:], label="Ref discharge HBV-bmi")
ax.set_ylabel('Discharge (mm/d)')
ax.legend(bbox_to_anchor=(1,1))

# %% [markdown]
# ## 2. Check whether your code is correct
#
# If the above looks reasonable, you probably have a good implementation of HBV. We can test if your HBV works as intended by running it through a scenario with pre-determined inital conditions and parameters. If the cells below can run without any assertions or erros, your model most likely works as intended. These kind of test are often used in software engineering to test if code behaves as intended.
#
# To test your HBV model, run the next cell. This is an example with different parameters and initial storages, to see if your implemented function works properly.
#
# In this example, the interception storage is filled with 15 mm of water and the unsaturated rootzone storage is initally set to 60 mm. The other storages are empty at the initial state. By using the parameter set given below, the water will divide over the other storages. Have a look at the chosen initial conditions and parameters. You should be able to calculate by hand what the storages are supposed to be after one timestep.
#
# The ```assert``` lines test if your HBV does indeed give the expected results.

# %%
forcing_test = HBVForcing(start_time = experiment_start_date,
                          end_time = experiment_end_date,
                          directory = forcing_path,
                          camels_file = f'Forcing_test.txt',
                          test_data_bool = True
                          )

model_test = HBV(forcing=forcing_test)

param_names = ["Imax","Ce",  "Sumax", "beta",  "Pmax",  "Tlag",   "Kf",   "Ks"]
parameters_test = np.array([5,   0.35,  100,    1,   20,   5,     0.1,  0.4])

S_names = ["Interception storage", "Unsaturated Rootzone Storage", "Fastflow storage", "Groundwater storage"]
initial_storage_test = np.array([15,  60,  0,  0])


config_file_test, _ = model_test.setup(
                            parameters=','.join([str(p) for p in parameters_test]),
                            initial_storage=','.join([str(s) for s in initial_storage_test]),
                               )
model_test.initialize(config_file_test)

model_test.update()


assert np.isclose(model_test.get_value('Pe_dt'), 25, rtol=1e-4, atol=1e-4)
assert np.isclose(model_test.get_value('Ei_dt'), 0, rtol=1e-4, atol=1e-4)
assert np.isclose(model_test.get_value('Ea_dt'), 20, rtol=1e-4, atol=1e-4)

assert np.isclose(model_test.get_value('Si'), 5, rtol=1e-4, atol=1e-4)
assert np.isclose(model_test.get_value('Sf'), 13.5, rtol=1e-4, atol=1e-4)
assert np.isclose(model_test.get_value('Su'), 40, rtol=1e-4, atol=1e-4)
assert np.isclose(model_test.get_value('Ss'), 6, rtol=1e-4, atol=1e-4)

assert np.isclose(model_test.get_value("Qus_dt"), 10, rtol=1e-4, atol=1e-4)
assert np.isclose(model_test.get_value('Qf_dt'), 1.5, rtol=1e-4, atol=1e-4)
assert np.isclose(model_test.get_value('Qs_dt'), 4, rtol=1e-4, atol=1e-4)

model_test.finalize()

# %% [markdown]
# ## 3. Create your own test (optionally)
#
# You can also create a test case yourself. In the code cell below, a structure is made to create your own test case. In the first cell, you have to choose initial parameters and initial storages. With these input parametes you can calculate the outcome values after one timestep by hand. Fill in these values at the designated location in the first cell. You need to run the second cell to see if you correctly created a test case. If it does not raise an assertion, you succeeded.
# If an assertion raises and this did not raise in the predefined test case, you probably made an error in your hand calculations.
#
# For the first timestep, the precipitation and potential evaporation are equal to **15 mm and 10 mm** respectively. Use these in your hand-calculations. In the HBV model, it is automatically read from the ```Forcing_test.txt``` file.

# %%
def own_test():
    forcing_test = HBVForcing(start_time = experiment_start_date,
                              end_time = experiment_end_date,
                              directory = forcing_path,
                              camels_file = f'Forcing_test.txt',
                              test_data_bool = True
                              )
    
    model_test_own = HBV(forcing=forcing_test)
    
    param_names = ["Imax","Ce",  "Sumax", "beta",  "Pmax",  "Tlag",   "Kf",   "Ks"]
    parameters_test = np.array([0,0,0,0,0,0,0,0])  # choose parameters yourself 
    
    S_names = ["Interception storage", "Unsaturated Rootzone Storage", "Fastflow storage", "Groundwater storage"]
    initial_storage_test = np.array([0,0,0,0])  # choose the initial storages yourself
    
    config_file_test, _ = model_test_own.setup(
                                parameters=','.join([str(p) for p in parameters_test]),
                                initial_storage=','.join([str(s) for s in initial_storage_test]),
                                   )
    model_test_own.initialize(config_file_test)
    
    model_test_own.update()

    # Fill in the values that occur after one timestep
    Pe = 0
    Ei = 0
    Ea = 0
    Si = 0
    Sf = 0
    Su = 0
    Ss = 0
    Qus_dt = 0
    Qf_dt = 0
    Qs_dt = 0
    
    ans_list = [Pe, Ei, Ea, Si, Sf, Su, Ss, Qus_dt, Qf_dt, Qs_dt]
    model_test_own.finalize()

    return ans_list

# %%
answer = own_test()

### BEGIN HIDDEN TESTS
def check(list):

    Pe = list[0]
    Ei = list[1]
    Ea = list[2]
    Si = list[3]
    Sf = list[4]
    Su = list[5]
    Ss = list[6]
    Qus_dt = list[7]
    Qf_dt = list[8]
    Qs_dt = list[9]
    
    
    assert np.isclose(Pe, 0, rtol=1e-4, atol=1e-4)
    assert np.isclose(Ei, 0, rtol=1e-4, atol=1e-4)
    assert np.isclose(Ea, 0, rtol=1e-4, atol=1e-4)
    
    assert np.isclose(Si, 0, rtol=1e-4, atol=1e-4)
    assert np.isclose(Sf, 0, rtol=1e-4, atol=1e-4)
    assert np.isclose(Su, 0, rtol=1e-4, atol=1e-4)
    assert np.isclose(Ss, 0, rtol=1e-4, atol=1e-4)
    
    assert np.isclose(Qus_dt, 0, rtol=1e-4, atol=1e-4)
    assert np.isclose(Qf_dt, 0, rtol=1e-4, atol=1e-4)
    assert np.isclose(Qs_dt, 0, rtol=1e-4, atol=1e-4)
### END HIDDEN TESTS

check(answer)

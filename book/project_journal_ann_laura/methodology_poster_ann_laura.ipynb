# %% [markdown]
# # THE IMPACT OF 2019 AUSTRALIAN EAST COAST BUSHFIRES ON RIVER DISCHARGE IN THE MANNING RIVER CATCHMENT

# %% [markdown]
# Laura Spoelstra 5547504 and Ann Jones 6167543

# %% [markdown]
# ## Research Objective

# %% [markdown]
# The Manning River catchment, located in New South Wales, represents a hydrological system in which vegetation plays an important role in regulating water flows. Vegetation influences processes such as interception, infiltration, soil moisture storage, and evapotranspiration, which together determine how rainfall is divided between runoff and evaporation. Changes in vegetation can therefore directly affect discharge.
#
# A big disturbance to vegetation occurred during the 2019–2020 Australian east coast bushfires, which were unprecedented in both scale and intensity. During this event, hectares of forest were burned across eastern Australia, with approximately 21% of the temperate broadleaf forest biome affected in a single fire season far exceeding historical observations (Boer et al., 2020). These extreme conditions were driven by prolonged drought and very low fuel moisture, allowing fires to spread into areas that are normally less vulnerable to burning. As a result, large parts of catchments like the Manning experienced vegetation loss.
#
# Such vegetation loss can affect hydrological processes by reducing interception and evapotranspiration, and by lowering soil infiltration capacity. This can increase surface runoff and potentially lead to higher peak discharges after rainfall events. Studies have shown that fire-induced vegetation loss can increase streamflow responses, although the strength of this effect depends on catchment characteristics and recovery processes (Nolan et al., 2020).
#
# However, it is still unclear to what extent these changes can be observed in discharge data. Hydrological responses may be influenced by climate variability or other processes.
#
# This leads to the central research question: *To what extent did the 2019–2020 bushfires influence the discharge behavior of the Manning River catchment, and can these effects be identified in observed hydrological data?*

# %% [markdown]
# ## Catchment Description

# %% [markdown]
# The Manning River catchment is located in New South Wales, Australia, and drains eastward into the Tasman Sea. The river originates in the elevated and forested regions of the Barrington Tops within the Great Dividing Range. These headwaters are characterized by steep terrain and relatively high rainfall (NSW, 2021).
#
# From these upland areas, the river flows east and southeast through a varied landscape of forested slopes, agricultural valleys, and rural settlements. Along its course, it passes regional centers such as Wingham and Taree, where it supports irrigation, fisheries, and local communities, before reaching the coast near Harrington and Old Bar.
#
# The catchment has a dense drainage network and steep upper areas, which will impact the rainfall. Land use varies from mainly forest in the upper catchment to agricultural and semi-urban areas in the lower basin.
#
# For this study, the focus is on the sub-catchment corresponding to the Killawarra gauging station with an area of 6642 km$^2$, which represents the upstream area used for discharge measurements. The catchment is located approximately between 31.5°S to 32.5°S latitude and 151.5°E to 152.5°E longitude.

# %% [markdown]
# ## Data Collection

# %% [markdown]
# To answer this research question, several types of data were needed:
# - Precipitation & evaporation. Source: ERA5
# - Discharge. Source: GRDC - Killawarra Station
#
# The ERA5 data is forced and saved in the 'Forcing' file, together with the shapefile of the Cagayan de Oro catchment.

# %% [markdown]
# ## Deforestation Data & Analysis

# %% [markdown]
# The Land Cover Classification Gridded Maps from 1992 to present, derived from satellite observations and provided by Copernicus Climate Data Store (version 2.1.1), are used to analyse land use transitions in QGIS (Copernicus Climate Data Store, n.d.). The spatial resolution of the Copernicus dataset is 300 meters, meaning that each pixel represents an area of 300 × 300 meters. Therefore, each pixel in forest cover corresponds to this spatial scale. These results are compared with the European Space Agency WorldCover dataset, which provides even higher resolution (10 m per pixel) global land cover information (ESA, 2021). The ESA worldcover landuse data could not been used for the comparison of the landuse, since one 2020 and 2021 were available there.
#
# These types of land use changes are analysed:
#
# Deforestation: \
# Conversion from forest to other land use types, shown in red on the left map. \
# Reforestation: \
# Conversion from non-forest land (cropland or shrubland) back to forest, shown in green on the left map.
#
# The WorldCover map shows that most non-forest areas in the catchment consist of cropland and shrubland. This indicates that deforestation mainly results in a transition to less diverse vegetation types, rather than urban areas.
#
# The spatial resolution of the Copernicus dataset is 300 meters, meaning that each pixel represents an area of 300 × 300 meters. Therefore, each pixel in forest cover corresponds to this spatial scale.
#
# <div style="display: flex; align-items: stretch; justify-content: center; gap: 10px;">
#
#   <div style="text-align: center;">
#     <img src="Images/Map%20Manning.png" width="500">
#     <p style="font-size: 13px; margin-top: 5px;">
#       Manning River catchment with Killawarra catchment highlighted
#     </p>
#   </div>
#
#   <div style="width: 15px; background-color: white;"></div>
#
#   <div style="text-align: center;">
#     <img src="Images/australia.png" width="300">
#     <p style="font-size: 13px; margin-top: 5px;">
#          Manning catchment situated in Australia
#     </p>
#   </div>
#
# </div>

# %% [markdown]
# ## Influence of Deforestation on Catchment Dynamics

# %% [markdown]
# To analyse whether the impact of the deforestation at the end of 2019 and the start of 2020 can be seen in the Manning watershed, several different catchment characteristics were investigated pre- and post-deforestation. The following effects were analysed:
# - River discharge (*PROJECT_ANALYSIS.ipynb*)
# - Run-off coefficient (*PROJECT_ANALYSIS.ipynb*)
# - Rootzone storage (*PROJECT_ANALYSIS.ipynb*)
# - Budyko plots (*PROJECT_ANALYSIS.ipynb*)
# - Calibration of the models --> Su,max of discharge models (*PRE_DEFORESTATION.ipynb* and *POST_DEFORESTATION.ipynb*)

# %% [markdown]
# ### River Discharge

# %% [markdown]
# The river discharge timeseries for around 5 years pre- and 5 years post-deforestation were plotted to see whether a significant change can be seen.

# %% [markdown]
# INSERT DISCHARGE PICTURE

# %% [markdown]
# EXPLANATION DISCHRAGE Blalblabla

# %% [markdown]
# It can be seen that big changes in mean river discharge occur at other times in the discharge data as well. Thus, it can be that the increase in mean discharge is because of deforestation, but it is not possible to say this for certain as there are also many other factors (e.g. precipitation) that affect discharge magnitudes.

# %% [markdown]
# ### Run-off Coefficient

# %% [markdown]
# blabla

# %% [markdown]
# ![Runoff.png](runoff.png)

# %% [markdown]
# explanation

# %% [markdown]
# ### Rootzone Storage

# %% [markdown]
# The rootzone storage is in theory affected by deforestation. It is expected to decrease when forests are cut down. (INSERT SOURCE)

# %% [markdown]
# ![Root.png](storag.png)

# %% [markdown]
# blabla

# %% [markdown]
# ### Budyko Framework

# %% [markdown]
# blabla

# %% [markdown]
# ![Budyko.png](.png)

# %% [markdown]
# explain

# %% [markdown]
# ### Su,max of Discharge Models

# %% [markdown]
# The final stage of the analysis involved calibrating the discharge model for periods before and after deforestation, in order to assess whether changes in the Su,max (maximum unsaturated storage) parameter could be identified. To avoid long computation times, the calibration procedures were carried out in separate notebooks:
#
# Pre-deforestation calibration: CALIBRATION_PRE_DEFORESTATION.ipynb
# Post-deforestation calibration: CALIBRATION_POST_DEFORESTATION.ipynb
#
# These notebooks also include model validation for independent time periods.

# %% [markdown]
# The results of the calibation based on the De value:
# - Su,max pre-deforstation: .... mm
# - Su,max post-deforestation: ..... mm
#
# Su,max for the different parameters sets, according to best NSE, logNSE, De are visualised in the tables below.
#
# The pre-deforestation calibration has run for N=500.
# |                | NSE | logNSE | De |
# |:-:              |:-:  |:-:     |:-: |
# |Calibration value|..|..    |...|
# |Su,max Pre       |...|5..  |...|
#
# The post-deforestation has also been run with N=500.
# |                 | NSE | logNSE | De |
# |:-:              |:-:  |:-:     |:-: |
# |Calibration value|-...| -...  |1..|
# |Su,max Post      |...|5.. |5..|
#
# explain

# %% [markdown]
# ## Analysis Different Data Sources

# %% [markdown]
# As the above analysis sometimes raised questions about how good the data is, other data sources were collected to see if there is a dataset that performs better. This was done by appling the 'closing the water balance' method. This analysis can be found in: *comparing_datasources.ipynb*.
#
# The data sources used from Earth Engine are:
# - Precipitation:'NASA/GPM_L3/IMERG_V07', 'UCSB-CHG/CHIRPS/DAILY', 'ECMWF/ERA5_LAND/DAILY_AGGR'
# - Evaporation:'NASA_GLDAS_V021_NOAH_G025_T3H', 'ECMWF/ERA5_LAND/DAILY_AGGR', 'MODIS_061_MOD16A2GF', TERN_AET_CMRSET_LANDSAT_V2_2
# - Storage:'NASA/GRACE/MASS_GRIDS_V04/LAND' (lwe_thickness and uncertainty)

# %% [markdown]
# The Kalman filtering and smoothing is used to close the water balance. It can be seen that there is quite some variance between the different data sources and especially the precipitation data all falls quite often outside of the post exterior variance band.
#
#
#
# stillll want to compare data with BUDYKO???

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## References Papers

# %% [markdown]
# Boer, M. M., Resco de Dios, V., & Bradstock, R. A. (2020). Unprecedented burn area of Australian mega forest fires. Nature Climate Change, 10, 171–172. https://www.nature.com/articles/s41558-020-0716-1
#
# Nolan, R. H., et al. (2020). Causes and consequences of eastern Australia’s 2019–20 season of mega-fires. Global Change Biology. https://onlinelibrary.wiley.com/doi/10.1111/gcb.14987
#
# NSW Department of Planning and Environment. (2021). Manning River catchment and estuary management program 2021–2031.

# %% [markdown]
# ## References Data Sources

# %% [markdown]
# CHIRPS Daily Precipitation
# Climate Hazards Group. (n.d.). CHIRPS: Climate Hazards Group InfraRed Precipitation with Station data. University of California, Santa Barbara. https://www.chc.ucsb.edu/data/chirps
#
# Copernicus Climate Data Store. (n.d.). Land cover classification gridded maps from 1992 to present. https://cds.climate.copernicus.eu/datasets
# European Space Agency. (n.d.).
#
# CMRSET LANDSAT
#
# ERA5 Climate Reanalysis (Precipitation & Evaporation)
# Hersbach, H., Bell, B., Berrisford, P., et al. (2020). ERA5 hourly data on single levels from 1959 to present. Copernicus Climate Change Service (C3S). https://doi.org/10.24381/cds.adbb2d47
#
# ESA WorldCover product (2021) https://viewer.esa-worldcover.org/worldcover/
#
# GLDAS (Global Land Data Assimilation System)
# Rodell, M., Houser, P. R., Jambor, U., Gottschalck, J., Mitchell, K., Meng, C. J., ... & Toll, D. (2004). The Global Land Data Assimilation System. Bulletin of the American Meteorological Society, 85(3), 381–394. https://ldas.gsfc.nasa.gov/gldas
#
# GRACE Terrestrial Water Storage
# NASA Jet Propulsion Laboratory. (n.d.). GRACE Tellus Monthly Mass Grids. https://grace.jpl.nasa.gov
#
# MODIS Evapotranspiration (MOD16)
# Mu, Q., Zhao, M., & Running, S. W. (2011). MODIS global evapotranspiration (ET) product (MOD16A2) NASA Earth Observing System, Version 6. NASA EOSDIS Land Processes DAAC. https://doi.org/10.5067/MODIS/MOD16A2.006
#  IMERG Precipitation Data
# NASA. (n.d.). IMERG: Integrated Multi-satellitE Retrievals for GPM. https://gpm.nasa.gov/data/imerg
#
# WORLDCOVER ESA
#
# Discharge
# GRDC
#
# Australian Goverment as a reference
